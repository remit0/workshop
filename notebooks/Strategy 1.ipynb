# %%
import sys
sys.path.append('/Users/remirosenthal/workshop')

# %%
import pandas as pd

from workshop.io import get_data
from workshop.classes import init

# %% [markdown]
# # what we need
# - assign large families first -> family cost function is dependent on family size
# - identify families that are "tolerant" and those are not. (-> tolerant: diverse day choices)
# - assign large and intolerant families first
# - identify days that should be kept to a minimum (right before the weekend / holidays for acc penalty) + unwanted ones
# - secure min constraint first vs redistributing

# %%
data = get_data()
maker = init(data)

# %%
for day in range(1, 101):
    groups_scored = maker.evaluate_groups(day)
    for group, score in groups_scored:
        maker.assign(group, day)
        if maker.bookings.loc[day] >= maker.MIN:
            break

for group in maker.groups:
    day = maker.get_best_wish(group)
    if day > 0:
        maker.assign(group, day)
    else:
        day = maker.find_best_day(group)
        maker.assign(group, day)

maker.make_submission("strat1")
# Out:
# **assigned group number 66 to day 1.
# current bookings 8
# **assigned group number 250 to day 1.
# current bookings 16
# **assigned group number 504 to day 1.
# current bookings 24
# **assigned group number 1110 to day 1.
# current bookings 32
# **assigned group number 1477 to day 1.
# current bookings 40
# **assigned group number 1597 to day 1.
# current bookings 48
# **assigned group number 1653 to day 1.
# current bookings 56
# **assigned group number 1813 to day 1.
# current bookings 64
# **assigned group number 2698 to day 1.
# current bookings 72
# **assigned group number 2722 to day 1.
# current bookings 80
# **assigned group number 2762 to day 1.
# current bookings 88
# **assigned group number 2830 to day 1.
# current bookings 96
# **assigned group number 3306 to day 1.
# current bookings 104
# **assigned group number 3310 to day 1.
# current bookings 112
# **assigned group number 3472 to day 1.
# current bookings 120
# **assigned group number 3519 to day 1.
# current bookings 128
# **assigned group number 127 to day 2.
# current bookings 136
# **assigned group number 2519 to day 2.
# current bookings 144
# **assigned group number 873 to day 2.
# current bookings 152
# **assigned group number 1529 to day 2.
# current bookings 160
# **assigned group number 2404 to day 2.
# current bookings 168
# **assigned group number 2909 to day 2.
# current bookings 176
# **assigned group number 3792 to day 2.
# current bookings 184
# **assigned group number 350 to day 2.
# current bookings 192
# **assigned group number 3121 to day 2.
# current bookings 200
# **assigned group number 2642 to day 2.
# current bookings 208
# **assigned group number 4890 to day 2.
# current bookings 216
# **assigned group number 1186 to day 2.
# current bookings 223
# **assigned group number 1397 to day 2.
# current bookings 230
# **assigned group number 2993 to day 2.
# current bookings 237
# **assigned group number 2208 to day 2.
# current bookings 244
# **assigned group number 557 to day 2.
# current bookings 251
# **assigned group number 583 to day 2.
# current bookings 258
# **assigned group number 366 to day 3.
# current bookings 266
# **assigned group number 799 to day 3.
# current bookings 274
# **assigned group number 1137 to day 3.
# current bookings 282
# **assigned group number 3769 to day 3.
# current bookings 290
# **assigned group number 3491 to day 3.
# current bookings 298
# **assigned group number 2361 to day 3.
# current bookings 306
# **assigned group number 3279 to day 3.
# current bookings 314
# **assigned group number 939 to day 3.
# current bookings 322
# **assigned group number 1331 to day 3.
# current bookings 330
# **assigned group number 4518 to day 3.
# current bookings 338
# **assigned group number 2680 to day 3.
# current bookings 346
# **assigned group number 1974 to day 3.
# current bookings 354
# **assigned group number 3272 to day 3.
# current bookings 362
# **assigned group number 3662 to day 3.
# current bookings 370
# **assigned group number 3956 to day 3.
# current bookings 378
# **assigned group number 1572 to day 3.
# current bookings 386
# **assigned group number 878 to day 4.
# current bookings 394
# **assigned group number 3664 to day 4.
# current bookings 402
# **assigned group number 2456 to day 4.
# current bookings 410
# **assigned group number 874 to day 4.
# current bookings 418
# **assigned group number 4733 to day 4.
# current bookings 426
# **assigned group number 636 to day 4.
# current bookings 434
# **assigned group number 896 to day 4.
# current bookings 442
# **assigned group number 1353 to day 4.
# current bookings 450
# **assigned group number 4759 to day 4.
# current bookings 458
# **assigned group number 580 to day 4.
# current bookings 466
# **assigned group number 1422 to day 4.
# current bookings 474
# **assigned group number 3017 to day 4.
# current bookings 482
# **assigned group number 3186 to day 4.
# current bookings 490
# **assigned group number 1765 to day 4.
# current bookings 498
# **assigned group number 4078 to day 4.
# current bookings 506
# **assigned group number 1158 to day 4.
# current bookings 514
# **assigned group number 41 to day 5.
# current bookings 522
# **assigned group number 692 to day 5.
# current bookings 530
# **assigned group number 1099 to day 5.
# current bookings 538
# **assigned group number 3571 to day 5.
# current bookings 546
# **assigned group number 3742 to day 5.
# current bookings 554
# **assigned group number 3778 to day 5.
# current bookings 562
# **assigned group number 2198 to day 5.
# current bookings 570
# **assigned group number 42 to day 5.
# current bookings 578
# **assigned group number 1822 to day 5.
# current bookings 586
# **assigned group number 3063 to day 5.
# current bookings 594
# **assigned group number 660 to day 5.
# current bookings 602
# **assigned group number 2469 to day 5.
# current bookings 610
# **assigned group number 4312 to day 5.
# current bookings 618
# **assigned group number 1359 to day 5.
# current bookings 626
# **assigned group number 1621 to day 5.
# current bookings 634
# **assigned group number 3354 to day 5.
# current bookings 642
# **assigned group number 2819 to day 6.
# current bookings 650
# **assigned group number 3746 to day 6.
# current bookings 658
# **assigned group number 4543 to day 6.
# current bookings 666
# **assigned group number 1498 to day 6.
# current bookings 674
# **assigned group number 1268 to day 6.
# current bookings 682
# **assigned group number 787 to day 6.
# current bookings 689
# **assigned group number 2356 to day 6.
# current bookings 696
# **assigned group number 3464 to day 6.
# current bookings 703
# **assigned group number 4805 to day 6.
# current bookings 710
# **assigned group number 728 to day 6.
# current bookings 717
# **assigned group number 1209 to day 6.
# current bookings 724
# **assigned group number 2624 to day 6.
# current bookings 731
# **assigned group number 708 to day 6.
# current bookings 738
# **assigned group number 3495 to day 6.
# current bookings 745
# **assigned group number 1848 to day 6.
# current bookings 752
# **assigned group number 2062 to day 6.
# current bookings 759
# **assigned group number 4257 to day 6.
# current bookings 766
# **assigned group number 4321 to day 6.
# current bookings 773
# **assigned group number 1192 to day 7.
# current bookings 781
# **assigned group number 1840 to day 7.
# current bookings 789
# **assigned group number 1995 to day 7.
# current bookings 797
# **assigned group number 2021 to day 7.
# current bookings 805
# **assigned group number 3219 to day 7.
# current bookings 813
# **assigned group number 2115 to day 7.
# current bookings 821
# **assigned group number 2782 to day 7.
# current bookings 829
# **assigned group number 4302 to day 7.
# current bookings 837
# **assigned group number 1273 to day 7.
# current bookings 845
# **assigned group number 1276 to day 7.
# current bookings 852
# **assigned group number 1551 to day 7.
# current bookings 859
# **assigned group number 3004 to day 7.
# current bookings 866
# **assigned group number 4704 to day 7.
# current bookings 873
# **assigned group number 266 to day 7.
# current bookings 880
# **assigned group number 717 to day 7.
# current bookings 887
# **assigned group number 2362 to day 7.
# current bookings 894
# **assigned group number 4350 to day 7.
# current bookings 901
# **assigned group number 824 to day 8.
# current bookings 909
# **assigned group number 3796 to day 8.
# current bookings 917
# **assigned group number 1809 to day 8.
# current bookings 925
# **assigned group number 3609 to day 8.
# current bookings 933
# **assigned group number 1679 to day 8.
# current bookings 941
# **assigned group number 3297 to day 8.
# current bookings 949
# **assigned group number 3795 to day 8.
# current bookings 957
# **assigned group number 395 to day 8.
# current bookings 964
# **assigned group number 4020 to day 8.
# current bookings 971
# **assigned group number 2829 to day 8.
# current bookings 978
# **assigned group number 10 to day 8.
# current bookings 985
# **assigned group number 1394 to day 8.
# current bookings 992
# **assigned group number 2439 to day 8.
# current bookings 999
# **assigned group number 1945 to day 8.
# current bookings 1006
# **assigned group number 3813 to day 8.
# current bookings 1013
# **assigned group number 648 to day 8.
# current bookings 1020
# **assigned group number 2081 to day 8.
# current bookings 1027
# **assigned group number 2898 to day 9.
# current bookings 1035
# **assigned group number 1886 to day 9.
# current bookings 1042
# **assigned group number 2522 to day 9.
# current bookings 1049
# **assigned group number 3606 to day 9.
# current bookings 1056
# **assigned group number 4521 to day 9.
# current bookings 1063
# **assigned group number 1279 to day 9.
# current bookings 1070
# **assigned group number 1855 to day 9.
# current bookings 1077
# **assigned group number 1420 to day 9.
# current bookings 1085
# **assigned group number 4300 to day 9.
# current bookings 1092
# **assigned group number 4810 to day 9.
# current bookings 1099
# **assigned group number 491 to day 9.
# current bookings 1106
# **assigned group number 847 to day 9.
# current bookings 1113
# **assigned group number 2511 to day 9.
# current bookings 1120
# **assigned group number 3680 to day 9.
# current bookings 1127
# **assigned group number 4740 to day 9.
# current bookings 1134
# **assigned group number 84 to day 9.
# current bookings 1140
# **assigned group number 209 to day 9.
# current bookings 1146
# **assigned group number 1869 to day 9.
# current bookings 1152
# **assigned group number 295 to day 10.
# current bookings 1160
# **assigned group number 2899 to day 10.
# current bookings 1168
# **assigned group number 633 to day 10.
# current bookings 1175
# **assigned group number 2051 to day 10.
# current bookings 1182
# **assigned group number 2399 to day 10.
# current bookings 1189
# **assigned group number 3499 to day 10.
# current bookings 1196
# **assigned group number 654 to day 10.
# current bookings 1202
# **assigned group number 1833 to day 10.
# current bookings 1208
# **assigned group number 1903 to day 10.
# current bookings 1214
# **assigned group number 3288 to day 10.
# current bookings 1220
# **assigned group number 3309 to day 10.
# current bookings 1226
# **assigned group number 4310 to day 10.
# current bookings 1232
# **assigned group number 4329 to day 10.
# current bookings 1238
# **assigned group number 4345 to day 10.
# current bookings 1244
# **assigned group number 319 to day 10.
# current bookings 1249
# **assigned group number 841 to day 10.
# current bookings 1254
# **assigned group number 911 to day 10.
# current bookings 1259
# **assigned group number 1312 to day 10.
# current bookings 1264
# **assigned group number 2210 to day 10.
# current bookings 1269
# **assigned group number 2309 to day 10.
# current bookings 1274
# **assigned group number 2368 to day 10.
# current bookings 1279
# **assigned group number 486 to day 11.
# current bookings 1287
# **assigned group number 1648 to day 11.
# current bookings 1295
# **assigned group number 3122 to day 11.
# current bookings 1303
# **assigned group number 4561 to day 11.
# current bookings 1311
# **assigned group number 3989 to day 11.
# current bookings 1319
# **assigned group number 3638 to day 11.
# current bookings 1327
# **assigned group number 785 to day 11.
# current bookings 1335
# **assigned group number 4139 to day 11.
# current bookings 1343
# **assigned group number 3437 to day 11.
# current bookings 1351
# **assigned group number 265 to day 11.
# current bookings 1358
# **assigned group number 579 to day 11.
# current bookings 1365
# **assigned group number 1832 to day 11.
# current bookings 1372
# **assigned group number 4045 to day 11.
# current bookings 1379
# **assigned group number 4624 to day 11.
# current bookings 1386
# **assigned group number 3953 to day 11.
# current bookings 1394
# **assigned group number 1074 to day 11.
# current bookings 1401
# **assigned group number 3137 to day 11.
# current bookings 1408
# **assigned group number 1176 to day 12.
# current bookings 1416
# **assigned group number 4990 to day 12.
# current bookings 1424
# **assigned group number 2606 to day 12.
# current bookings 1432
# **assigned group number 4194 to day 12.
# current bookings 1440
# **assigned group number 870 to day 12.
# current bookings 1448
# **assigned group number 3595 to day 12.
# current bookings 1456
# **assigned group number 170 to day 12.
# current bookings 1463
# **assigned group number 431 to day 12.
# current bookings 1470
# **assigned group number 535 to day 12.
# current bookings 1477
# **assigned group number 755 to day 12.
# current bookings 1484
# **assigned group number 2571 to day 12.
# current bookings 1491
# **assigned group number 2726 to day 12.
# current bookings 1498
# **assigned group number 3289 to day 12.
# current bookings 1505
# **assigned group number 3295 to day 12.
# current bookings 1512
# **assigned group number 3454 to day 12.
# current bookings 1519
# **assigned group number 3927 to day 12.
# current bookings 1526
# **assigned group number 4370 to day 12.
# current bookings 1533
# **assigned group number 370 to day 13.
# current bookings 1541
# **assigned group number 4708 to day 13.
# current bookings 1548
# **assigned group number 158 to day 13.
# current bookings 1554
# **assigned group number 2321 to day 13.
# current bookings 1560
# **assigned group number 3003 to day 13.
# current bookings 1566
# **assigned group number 4396 to day 13.
# current bookings 1572
# **assigned group number 38 to day 13.
# current bookings 1577
# **assigned group number 481 to day 13.
# current bookings 1582
# **assigned group number 1947 to day 13.
# current bookings 1587
# **assigned group number 2939 to day 13.
# current bookings 1592
# **assigned group number 4060 to day 13.
# current bookings 1597
# **assigned group number 4170 to day 13.
# current bookings 1602
# **assigned group number 1028 to day 13.
# current bookings 1606
# **assigned group number 2116 to day 13.
# current bookings 1610
# **assigned group number 2341 to day 13.
# current bookings 1614
# **assigned group number 2434 to day 13.
# current bookings 1618
# **assigned group number 2893 to day 13.
# current bookings 1622
# **assigned group number 2908 to day 13.
# current bookings 1626
# **assigned group number 3501 to day 13.
# current bookings 1630
# **assigned group number 3538 to day 13.
# current bookings 1634
# **assigned group number 3554 to day 13.
# current bookings 1638
# **assigned group number 3797 to day 13.
# current bookings 1642
# **assigned group number 4051 to day 13.
# current bookings 1646
# **assigned group number 4304 to day 13.
# current bookings 1650
# **assigned group number 4677 to day 13.
# current bookings 1654
# **assigned group number 4999 to day 13.
# current bookings 1658
# **assigned group number 2256 to day 14.
# current bookings 1666
# **assigned group number 700 to day 14.
# current bookings 1673
# **assigned group number 711 to day 14.
# current bookings 1680
# **assigned group number 2435 to day 14.
# current bookings 1687
# **assigned group number 4965 to day 14.
# current bookings 1694
# **assigned group number 3120 to day 14.
# current bookings 1700
# **assigned group number 3552 to day 14.
# current bookings 1706
# **assigned group number 4118 to day 14.
# current bookings 1712
# **assigned group number 4979 to day 14.
# current bookings 1718
# **assigned group number 124 to day 14.
# current bookings 1723
# **assigned group number 1623 to day 14.
# current bookings 1728
# **assigned group number 2113 to day 14.
# current bookings 1733
# **assigned group number 3052 to day 14.
# current bookings 1738
# **assigned group number 3125 to day 14.
# current bookings 1743
# **assigned group number 3963 to day 14.
# current bookings 1748
# **assigned group number 4186 to day 14.
# current bookings 1753
# **assigned group number 4252 to day 14.
# current bookings 1758
# **assigned group number 4427 to day 14.
# current bookings 1763
# **assigned group number 4958 to day 14.
# current bookings 1768
# **assigned group number 166 to day 14.
# current bookings 1772
# **assigned group number 515 to day 14.
# current bookings 1776
# **assigned group number 705 to day 14.
# current bookings 1780
# **assigned group number 1077 to day 14.
# current bookings 1784
# **assigned group number 386 to day 15.
# current bookings 1792
# **assigned group number 1120 to day 15.
# current bookings 1800
# **assigned group number 4931 to day 15.
# current bookings 1808
# **assigned group number 1454 to day 15.
# current bookings 1816
# **assigned group number 1808 to day 15.
# current bookings 1824
# **assigned group number 2109 to day 15.
# current bookings 1831
# **assigned group number 2585 to day 15.
# current bookings 1838
# **assigned group number 3377 to day 15.
# current bookings 1845
# **assigned group number 1852 to day 15.
# current bookings 1853
# **assigned group number 381 to day 15.
# current bookings 1860
# **assigned group number 630 to day 15.
# current bookings 1867
# **assigned group number 2779 to day 15.
# current bookings 1874
# **assigned group number 4471 to day 15.
# current bookings 1881
# **assigned group number 172 to day 15.
# current bookings 1888
# **assigned group number 2983 to day 15.
# current bookings 1895
# **assigned group number 1081 to day 15.
# current bookings 1903
# **assigned group number 114 to day 15.
# current bookings 1909
# **assigned group number 3683 to day 16.
# current bookings 1917
# **assigned group number 2154 to day 16.
# current bookings 1924
# **assigned group number 130 to day 16.
# current bookings 1930
# **assigned group number 497 to day 16.
# current bookings 1936
# **assigned group number 2875 to day 16.
# current bookings 1942
# **assigned group number 4535 to day 16.
# current bookings 1948
# **assigned group number 2561 to day 16.
# current bookings 1953
# **assigned group number 2623 to day 16.
# current bookings 1958
# **assigned group number 2661 to day 16.
# current bookings 1963
# **assigned group number 3634 to day 16.
# current bookings 1968
# **assigned group number 3777 to day 16.
# current bookings 1973
# **assigned group number 3872 to day 16.
# current bookings 1978
# **assigned group number 3997 to day 16.
# current bookings 1983
# **assigned group number 4600 to day 16.
# current bookings 1988
# **assigned group number 4867 to day 16.
# current bookings 1993
# **assigned group number 527 to day 16.
# current bookings 1997
# **assigned group number 652 to day 16.
# current bookings 2001
# **assigned group number 957 to day 16.
# current bookings 2005
# **assigned group number 1018 to day 16.
# current bookings 2009
# **assigned group number 1043 to day 16.
# current bookings 2013
# **assigned group number 1199 to day 16.
# current bookings 2017
# **assigned group number 1200 to day 16.
# current bookings 2021
# **assigned group number 1867 to day 16.
# current bookings 2025
# **assigned group number 2106 to day 16.
# current bookings 2029
# **assigned group number 2202 to day 16.
# current bookings 2033
# **assigned group number 2282 to day 16.
# current bookings 2037
# **assigned group number 3332 to day 17.
# current bookings 2045
# **assigned group number 413 to day 17.
# current bookings 2053
# **assigned group number 1645 to day 17.
# current bookings 2061
# **assigned group number 1723 to day 17.
# current bookings 2069
# **assigned group number 134 to day 17.
# current bookings 2077
# **assigned group number 4416 to day 17.
# current bookings 2085
# **assigned group number 428 to day 17.
# current bookings 2093
# **assigned group number 2068 to day 17.
# current bookings 2101
# **assigned group number 4509 to day 17.
# current bookings 2109
# **assigned group number 129 to day 17.
# current bookings 2116
# **assigned group number 3764 to day 17.
# current bookings 2123
# **assigned group number 4240 to day 17.
# current bookings 2130
# **assigned group number 398 to day 17.
# current bookings 2137
# **assigned group number 506 to day 17.
# current bookings 2144
# **assigned group number 1095 to day 17.
# current bookings 2151
# **assigned group number 3639 to day 17.
# current bookings 2158
# **assigned group number 4414 to day 17.
# current bookings 2165
# **assigned group number 751 to day 18.
# current bookings 2173
# **assigned group number 1488 to day 18.
# current bookings 2181
# **assigned group number 686 to day 18.
# current bookings 2188
# **assigned group number 2674 to day 18.
# current bookings 2195
# **assigned group number 4662 to day 18.
# current bookings 2202
# **assigned group number 4966 to day 18.
# current bookings 2209
# **assigned group number 2778 to day 18.
# current bookings 2216
# **assigned group number 3898 to day 18.
# current bookings 2223
# **assigned group number 3932 to day 18.
# current bookings 2230
# **assigned group number 4324 to day 18.
# current bookings 2237
# **assigned group number 103 to day 18.
# current bookings 2244
# **assigned group number 4730 to day 18.
# current bookings 2251
# **assigned group number 2418 to day 18.
# current bookings 2258
# **assigned group number 2701 to day 18.
# current bookings 2265
# **assigned group number 2825 to day 18.
# current bookings 2272
# **assigned group number 68 to day 18.
# current bookings 2279
# **assigned group number 2747 to day 18.
# current bookings 2286
# **assigned group number 4290 to day 18.
# current bookings 2293
# **assigned group number 3468 to day 19.
# current bookings 2301
# **assigned group number 4866 to day 19.
# current bookings 2309
# **assigned group number 11 to day 19.
# current bookings 2316
# **assigned group number 2835 to day 19.
# current bookings 2323
# **assigned group number 2860 to day 19.
# current bookings 2330
# **assigned group number 758 to day 19.
# current bookings 2337
# **assigned group number 1632 to day 19.
# current bookings 2344
# **assigned group number 2749 to day 19.
# current bookings 2351
# **assigned group number 4468 to day 19.
# current bookings 2358
# **assigned group number 1381 to day 19.
# current bookings 2365
# **assigned group number 1987 to day 19.
# current bookings 2372
# **assigned group number 3580 to day 19.
# current bookings 2379
# **assigned group number 3692 to day 19.
# current bookings 2386
# **assigned group number 3702 to day 19.
# current bookings 2393
# **assigned group number 2688 to day 19.
# current bookings 2400
# **assigned group number 3290 to day 19.
# current bookings 2407
# **assigned group number 3570 to day 19.
# current bookings 2414
# **assigned group number 4278 to day 19.
# current bookings 2421
# **assigned group number 2318 to day 20.
# current bookings 2429
# **assigned group number 1738 to day 20.
# current bookings 2437
# **assigned group number 1521 to day 20.
# current bookings 2444
# **assigned group number 2314 to day 20.
# current bookings 2451
# **assigned group number 4911 to day 20.
# current bookings 2458
# **assigned group number 4303 to day 20.
# current bookings 2465
# **assigned group number 2754 to day 20.
# current bookings 2472
# **assigned group number 547 to day 20.
# current bookings 2479
# **assigned group number 1416 to day 20.
# current bookings 2486
# **assigned group number 2037 to day 20.
# current bookings 2493
# **assigned group number 3415 to day 20.
# current bookings 2500
# **assigned group number 4368 to day 20.
# current bookings 2507
# **assigned group number 2097 to day 20.
# current bookings 2514
# **assigned group number 4918 to day 20.
# current bookings 2521
# **assigned group number 2209 to day 20.
# current bookings 2528
# **assigned group number 3616 to day 20.
# current bookings 2535
# **assigned group number 4226 to day 20.
# current bookings 2542
# **assigned group number 4249 to day 20.
# current bookings 2549
# **assigned group number 1812 to day 21.
# current bookings 2557
# **assigned group number 1557 to day 21.
# current bookings 2564
# **assigned group number 4061 to day 21.
# current bookings 2571
# **assigned group number 201 to day 21.
# current bookings 2578
# **assigned group number 559 to day 21.
# current bookings 2585
# **assigned group number 1898 to day 21.
# current bookings 2592
# **assigned group number 3263 to day 21.
# current bookings 2599
# **assigned group number 4141 to day 21.
# current bookings 2606
# **assigned group number 165 to day 21.
# current bookings 2613
# **assigned group number 1626 to day 21.
# current bookings 2620
# **assigned group number 4653 to day 21.
# current bookings 2626
# **assigned group number 2638 to day 21.
# current bookings 2632
# **assigned group number 3185 to day 21.
# current bookings 2638
# **assigned group number 3209 to day 21.
# current bookings 2644
# **assigned group number 3945 to day 21.
# current bookings 2650
# **assigned group number 180 to day 21.
# current bookings 2656
# **assigned group number 1719 to day 21.
# current bookings 2662
# **assigned group number 3407 to day 21.
# current bookings 2668
# **assigned group number 4611 to day 21.
# current bookings 2674
# **assigned group number 2015 to day 22.
# current bookings 2681
# **assigned group number 3755 to day 22.
# current bookings 2687
# **assigned group number 4843 to day 22.
# current bookings 2693
# **assigned group number 474 to day 22.
# current bookings 2698
# **assigned group number 503 to day 22.
# current bookings 2703
# **assigned group number 1087 to day 22.
# current bookings 2708
# **assigned group number 1400 to day 22.
# current bookings 2713
# **assigned group number 1542 to day 22.
# current bookings 2718
# **assigned group number 2039 to day 22.
# current bookings 2723
# **assigned group number 3308 to day 22.
# current bookings 2728
# **assigned group number 3774 to day 22.
# current bookings 2733
# **assigned group number 4128 to day 22.
# current bookings 2738
# **assigned group number 4390 to day 22.
# current bookings 2743
# **assigned group number 4668 to day 22.
# current bookings 2748
# **assigned group number 115 to day 22.
# current bookings 2752
# **assigned group number 334 to day 22.
# current bookings 2756
# **assigned group number 542 to day 22.
# current bookings 2760
# **assigned group number 2441 to day 22.
# current bookings 2764
# **assigned group number 2760 to day 22.
# current bookings 2768
# **assigned group number 2776 to day 22.
# current bookings 2772
# **assigned group number 3049 to day 22.
# current bookings 2776
# **assigned group number 3565 to day 22.
# current bookings 2780
# **assigned group number 3657 to day 22.
# current bookings 2784
# **assigned group number 3761 to day 22.
# current bookings 2788
# **assigned group number 4378 to day 22.
# current bookings 2792
# **assigned group number 4630 to day 22.
# current bookings 2796
# **assigned group number 281 to day 22.
# current bookings 2799
# **assigned group number 344 to day 23.
# current bookings 2806
# **assigned group number 1480 to day 23.
# current bookings 2813
# **assigned group number 4705 to day 23.
# current bookings 2820
# **assigned group number 333 to day 23.
# current bookings 2826
# **assigned group number 1421 to day 23.
# current bookings 2832
# **assigned group number 4738 to day 23.
# current bookings 2838
# **assigned group number 4834 to day 23.
# current bookings 2844
# **assigned group number 202 to day 23.
# current bookings 2849
# **assigned group number 537 to day 23.
# current bookings 2854
# **assigned group number 593 to day 23.
# current bookings 2859
# **assigned group number 679 to day 23.
# current bookings 2864
# **assigned group number 760 to day 23.
# current bookings 2869
# **assigned group number 1060 to day 23.
# current bookings 2874
# **assigned group number 1325 to day 23.
# current bookings 2879
# **assigned group number 1440 to day 23.
# current bookings 2884
# **assigned group number 2475 to day 23.
# current bookings 2889
# **assigned group number 2641 to day 23.
# current bookings 2894
# **assigned group number 3674 to day 23.
# current bookings 2899
# **assigned group number 3801 to day 23.
# current bookings 2904
# **assigned group number 210 to day 23.
# current bookings 2908
# **assigned group number 941 to day 23.
# current bookings 2912
# **assigned group number 1040 to day 23.
# current bookings 2916
# **assigned group number 1150 to day 23.
# current bookings 2920
# **assigned group number 1267 to day 23.
# current bookings 2924
# **assigned group number 958 to day 24.
# current bookings 2932
# **assigned group number 1131 to day 24.
# current bookings 2939
# **assigned group number 1769 to day 24.
# current bookings 2946
# **assigned group number 2505 to day 24.
# current bookings 2953
# **assigned group number 2949 to day 24.
# current bookings 2960
# **assigned group number 122 to day 24.
# current bookings 2966
# **assigned group number 422 to day 24.
# current bookings 2972
# **assigned group number 519 to day 24.
# current bookings 2978
# **assigned group number 2275 to day 24.
# current bookings 2984
# **assigned group number 2811 to day 24.
# current bookings 2990
# **assigned group number 3059 to day 24.
# current bookings 2996
# **assigned group number 3342 to day 24.
# current bookings 3002
# **assigned group number 3465 to day 24.
# current bookings 3008
# **assigned group number 4196 to day 24.
# current bookings 3014
# **assigned group number 4204 to day 24.
# current bookings 3020
# **assigned group number 415 to day 24.
# current bookings 3025
# **assigned group number 840 to day 24.
# current bookings 3030
# **assigned group number 859 to day 24.
# current bookings 3035
# **assigned group number 1062 to day 24.
# current bookings 3040
# **assigned group number 1456 to day 24.
# current bookings 3045
# **assigned group number 2040 to day 24.
# current bookings 3050
# **assigned group number 806 to day 25.
# current bookings 3058
# **assigned group number 4977 to day 25.
# current bookings 3066
# **assigned group number 2813 to day 25.
# current bookings 3073
# **assigned group number 3092 to day 25.
# current bookings 3080
# **assigned group number 2031 to day 25.
# current bookings 3088
# **assigned group number 228 to day 25.
# current bookings 3095
# **assigned group number 430 to day 25.
# current bookings 3102
# **assigned group number 613 to day 25.
# current bookings 3109
# **assigned group number 4490 to day 25.
# current bookings 3116
# **assigned group number 2183 to day 25.
# current bookings 3123
# **assigned group number 1925 to day 25.
# current bookings 3130
# **assigned group number 40 to day 25.
# current bookings 3136
# **assigned group number 569 to day 25.
# current bookings 3142
# **assigned group number 1000 to day 25.
# current bookings 3148
# **assigned group number 1108 to day 25.
# current bookings 3154
# **assigned group number 1761 to day 25.
# current bookings 3160
# **assigned group number 1768 to day 25.
# current bookings 3166
# **assigned group number 1815 to day 25.
# current bookings 3172
# **assigned group number 2088 to day 25.
# current bookings 3178
# **assigned group number 4337 to day 26.
# current bookings 3186
# **assigned group number 620 to day 26.
# current bookings 3193
# **assigned group number 1464 to day 26.
# current bookings 3200
# **assigned group number 2678 to day 26.
# current bookings 3207
# **assigned group number 4819 to day 26.
# current bookings 3214
# **assigned group number 1090 to day 26.
# current bookings 3221
# **assigned group number 1190 to day 26.
# current bookings 3228
# **assigned group number 1899 to day 26.
# current bookings 3235
# **assigned group number 3068 to day 26.
# current bookings 3242
# **assigned group number 1959 to day 26.
# current bookings 3249
# **assigned group number 9 to day 26.
# current bookings 3256
# **assigned group number 2442 to day 26.
# current bookings 3263
# **assigned group number 1807 to day 26.
# current bookings 3270
# **assigned group number 4798 to day 26.
# current bookings 3277
# **assigned group number 2494 to day 26.
# current bookings 3284
# **assigned group number 196 to day 26.
# current bookings 3290
# **assigned group number 368 to day 26.
# current bookings 3296
# **assigned group number 556 to day 26.
# current bookings 3302
# **assigned group number 1368 to day 26.
# current bookings 3308
# **assigned group number 351 to day 27.
# current bookings 3315
# **assigned group number 1302 to day 27.
# current bookings 3322
# **assigned group number 1404 to day 27.
# current bookings 3329
# **assigned group number 4699 to day 27.
# current bookings 3336
# **assigned group number 1249 to day 27.
# current bookings 3343
# **assigned group number 3360 to day 27.
# current bookings 3350
# **assigned group number 3821 to day 27.
# current bookings 3357
# **assigned group number 1362 to day 27.
# current bookings 3364
# **assigned group number 3918 to day 27.
# current bookings 3371
# **assigned group number 442 to day 27.
# current bookings 3378
# **assigned group number 3489 to day 27.
# current bookings 3385
# **assigned group number 507 to day 27.
# current bookings 3392
# **assigned group number 3066 to day 27.
# current bookings 3399
# **assigned group number 819 to day 27.
# current bookings 3407
# **assigned group number 1189 to day 27.
# current bookings 3415
# **assigned group number 1436 to day 27.
# current bookings 3423
# **assigned group number 1472 to day 27.
# current bookings 3431
# **assigned group number 1559 to day 27.
# current bookings 3439
# **assigned group number 4266 to day 28.
# current bookings 3446
# **assigned group number 4658 to day 28.
# current bookings 3453
# **assigned group number 3528 to day 28.
# current bookings 3460
# **assigned group number 3804 to day 28.
# current bookings 3467
# **assigned group number 4993 to day 28.
# current bookings 3474
# **assigned group number 2609 to day 28.
# current bookings 3481
# **assigned group number 1567 to day 28.
# current bookings 3488
# **assigned group number 4126 to day 28.
# current bookings 3495
# **assigned group number 2422 to day 28.
# current bookings 3502
# **assigned group number 2182 to day 28.
# current bookings 3510
# **assigned group number 2347 to day 28.
# current bookings 3518
# **assigned group number 3033 to day 28.
# current bookings 3526
# **assigned group number 4383 to day 28.
# current bookings 3534
# **assigned group number 4598 to day 28.
# current bookings 3542
# **assigned group number 947 to day 28.
# current bookings 3548
# **assigned group number 304 to day 28.
# current bookings 3554
# **assigned group number 831 to day 28.
# current bookings 3560
# **assigned group number 1839 to day 28.
# current bookings 3566
# **assigned group number 4837 to day 29.
# current bookings 3573
# **assigned group number 102 to day 29.
# current bookings 3580
# **assigned group number 642 to day 29.
# current bookings 3587
# **assigned group number 4577 to day 29.
# current bookings 3594
# **assigned group number 1753 to day 29.
# current bookings 3601
# **assigned group number 216 to day 29.
# current bookings 3608
# **assigned group number 4820 to day 29.
# current bookings 3615
# **assigned group number 387 to day 29.
# current bookings 3622
# **assigned group number 385 to day 29.
# current bookings 3628
# **assigned group number 2443 to day 29.
# current bookings 3634
# **assigned group number 2809 to day 29.
# current bookings 3640
# **assigned group number 3973 to day 29.
# current bookings 3646
# **assigned group number 4398 to day 29.
# current bookings 3652
# **assigned group number 4012 to day 29.
# current bookings 3659
# **assigned group number 2474 to day 29.
# current bookings 3665
# **assigned group number 4094 to day 29.
# current bookings 3671
# **assigned group number 339 to day 29.
# current bookings 3677
# **assigned group number 1146 to day 29.
# current bookings 3683
# **assigned group number 1411 to day 29.
# current bookings 3689
# **assigned group number 1528 to day 29.
# current bookings 3695
# **assigned group number 2245 to day 30.
# current bookings 3702
# **assigned group number 4719 to day 30.
# current bookings 3709
# **assigned group number 1829 to day 30.
# current bookings 3716
# **assigned group number 3957 to day 30.
# current bookings 3723
# **assigned group number 4052 to day 30.
# current bookings 3730
# **assigned group number 237 to day 30.
# current bookings 3737
# **assigned group number 4539 to day 30.
# current bookings 3744
# **assigned group number 4839 to day 30.
# current bookings 3751
# **assigned group number 1640 to day 30.
# current bookings 3757
# **assigned group number 1713 to day 30.
# current bookings 3763
# **assigned group number 2369 to day 30.
# current bookings 3769
# **assigned group number 4403 to day 30.
# current bookings 3775
# **assigned group number 246 to day 30.
# current bookings 3781
# **assigned group number 2049 to day 30.
# current bookings 3787
# **assigned group number 247 to day 30.
# current bookings 3793
# **assigned group number 971 to day 30.
# current bookings 3799
# **assigned group number 2739 to day 30.
# current bookings 3805
# **assigned group number 3138 to day 30.
# current bookings 3811
# **assigned group number 4439 to day 30.
# current bookings 3817
# **assigned group number 4800 to day 30.
# current bookings 3823
# **assigned group number 661 to day 31.
# current bookings 3830
# **assigned group number 4254 to day 31.
# current bookings 3837
# **assigned group number 822 to day 31.
# current bookings 3844
# **assigned group number 3036 to day 31.
# current bookings 3851
# **assigned group number 4549 to day 31.
# current bookings 3858
# **assigned group number 198 to day 31.
# current bookings 3865
# **assigned group number 3096 to day 31.
# current bookings 3872
# **assigned group number 1874 to day 31.
# current bookings 3879
# **assigned group number 846 to day 31.
# current bookings 3886
# **assigned group number 1691 to day 31.
# current bookings 3893
# **assigned group number 4224 to day 31.
# current bookings 3900
# **assigned group number 719 to day 31.
# current bookings 3907
# **assigned group number 2882 to day 31.
# current bookings 3913
# **assigned group number 3276 to day 31.
# current bookings 3919
# **assigned group number 4111 to day 31.
# current bookings 3925
# **assigned group number 4313 to day 31.
# current bookings 3931
# **assigned group number 4660 to day 31.
# current bookings 3937
# **assigned group number 4701 to day 31.
# current bookings 3943
# **assigned group number 219 to day 31.
# current bookings 3949
# **assigned group number 1136 to day 32.
# current bookings 3956
# **assigned group number 3950 to day 32.
# current bookings 3963
# **assigned group number 4046 to day 32.
# current bookings 3970
# **assigned group number 3752 to day 32.
# current bookings 3977
# **assigned group number 3611 to day 32.
# current bookings 3984
# **assigned group number 2694 to day 32.
# current bookings 3991
# **assigned group number 4826 to day 32.
# current bookings 3998
# **assigned group number 594 to day 32.
# current bookings 4005
# **assigned group number 1593 to day 32.
# current bookings 4012
# **assigned group number 3155 to day 32.
# current bookings 4019
# **assigned group number 3990 to day 32.
# current bookings 4026
# **assigned group number 729 to day 32.
# current bookings 4032
# **assigned group number 1961 to day 32.
# current bookings 4038
# **assigned group number 2589 to day 32.
# current bookings 4044
# **assigned group number 2824 to day 32.
# current bookings 4050
# **assigned group number 3469 to day 32.
# current bookings 4056
# **assigned group number 4659 to day 32.
# current bookings 4062
# **assigned group number 4997 to day 32.
# current bookings 4068
# **assigned group number 680 to day 32.
# current bookings 4074
# **assigned group number 715 to day 33.
# current bookings 4081
# **assigned group number 4776 to day 33.
# current bookings 4088
# **assigned group number 426 to day 33.
# current bookings 4094
# **assigned group number 868 to day 33.
# current bookings 4100
# **assigned group number 926 to day 33.
# current bookings 4106
# **assigned group number 2122 to day 33.
# current bookings 4112
# **assigned group number 3583 to day 33.
# current bookings 4118
# **assigned group number 4420 to day 33.
# current bookings 4124
# **assigned group number 4654 to day 33.
# current bookings 4130
# **assigned group number 4849 to day 33.
# current bookings 4136
# **assigned group number 248 to day 33.
# current bookings 4141
# **assigned group number 453 to day 33.
# current bookings 4146
# **assigned group number 475 to day 33.
# current bookings 4151
# **assigned group number 1092 to day 33.
# current bookings 4156
# **assigned group number 1470 to day 33.
# current bookings 4161
# **assigned group number 1530 to day 33.
# current bookings 4166
# **assigned group number 1681 to day 33.
# current bookings 4171
# **assigned group number 1973 to day 33.
# current bookings 4176
# **assigned group number 2263 to day 33.
# current bookings 4181
# **assigned group number 2273 to day 33.
# current bookings 4186
# **assigned group number 2283 to day 33.
# current bookings 4191
# **assigned group number 2653 to day 33.
# current bookings 4196
# **assigned group number 2671 to day 33.
# current bookings 4201
# **assigned group number 4870 to day 34.
# current bookings 4208
# **assigned group number 2207 to day 34.
# current bookings 4215
# **assigned group number 4691 to day 34.
# current bookings 4222
# **assigned group number 2558 to day 34.
# current bookings 4228
# **assigned group number 174 to day 34.
# current bookings 4234
# **assigned group number 2783 to day 34.
# current bookings 4240
# **assigned group number 3874 to day 34.
# current bookings 4246
# **assigned group number 4284 to day 34.
# current bookings 4252
# **assigned group number 1864 to day 34.
# current bookings 4258
# **assigned group number 1979 to day 34.
# current bookings 4264
# **assigned group number 3056 to day 34.
# current bookings 4270
# **assigned group number 3369 to day 34.
# current bookings 4276
# **assigned group number 3473 to day 34.
# current bookings 4282
# **assigned group number 1377 to day 34.
# current bookings 4288
# **assigned group number 3798 to day 34.
# current bookings 4294
# **assigned group number 4603 to day 34.
# current bookings 4300
# **assigned group number 1430 to day 34.
# current bookings 4306
# **assigned group number 4034 to day 34.
# current bookings 4312
# **assigned group number 4152 to day 34.
# current bookings 4318
# **assigned group number 2004 to day 34.
# current bookings 4324
# **assigned group number 4168 to day 34.
# current bookings 4330
# **assigned group number 1012 to day 35.
# current bookings 4337
# **assigned group number 3339 to day 35.
# current bookings 4344
# **assigned group number 3966 to day 35.
# current bookings 4351
# **assigned group number 79 to day 35.
# current bookings 4358
# **assigned group number 1292 to day 35.
# current bookings 4364
# **assigned group number 1728 to day 35.
# current bookings 4370
# **assigned group number 2079 to day 35.
# current bookings 4376
# **assigned group number 3335 to day 35.
# current bookings 4382
# **assigned group number 4038 to day 35.
# current bookings 4388
# **assigned group number 1269 to day 35.
# current bookings 4394
# **assigned group number 2750 to day 35.
# current bookings 4400
# **assigned group number 516 to day 35.
# current bookings 4406
# **assigned group number 923 to day 35.
# current bookings 4412
# **assigned group number 1662 to day 35.
# current bookings 4418
# **assigned group number 3916 to day 35.
# current bookings 4424
# **assigned group number 3225 to day 35.
# current bookings 4430
# **assigned group number 2289 to day 35.
# current bookings 4437
# **assigned group number 1042 to day 35.
# current bookings 4443
# **assigned group number 1685 to day 35.
# current bookings 4449
# **assigned group number 3873 to day 35.
# current bookings 4455
# **assigned group number 754 to day 36.
# current bookings 4461
# **assigned group number 821 to day 36.
# current bookings 4467
# **assigned group number 2736 to day 36.
# current bookings 4473
# **assigned group number 4376 to day 36.
# current bookings 4479
# **assigned group number 1166 to day 36.
# current bookings 4484
# **assigned group number 2027 to day 36.
# current bookings 4489
# **assigned group number 2103 to day 36.
# current bookings 4494
# **assigned group number 3521 to day 36.
# current bookings 4499
# **assigned group number 3660 to day 36.
# current bookings 4504
# **assigned group number 4684 to day 36.
# current bookings 4509
# **assigned group number 466 to day 36.
# current bookings 4513
# **assigned group number 830 to day 36.
# current bookings 4517
# **assigned group number 1767 to day 36.
# current bookings 4521
# **assigned group number 2143 to day 36.
# current bookings 4525
# **assigned group number 3023 to day 36.
# current bookings 4529
# **assigned group number 3311 to day 36.
# current bookings 4533
# **assigned group number 222 to day 36.
# current bookings 4536
# **assigned group number 2847 to day 36.
# current bookings 4539
# **assigned group number 3563 to day 36.
# current bookings 4542
# **assigned group number 3731 to day 36.
# current bookings 4545
# **assigned group number 3802 to day 36.
# current bookings 4548
# **assigned group number 393 to day 36.
# current bookings 4550
# **assigned group number 1665 to day 36.
# current bookings 4552
# **assigned group number 2206 to day 36.
# current bookings 4554
# **assigned group number 2989 to day 36.
# current bookings 4556
# **assigned group number 4905 to day 36.
# current bookings 4558
# **assigned group number 1544 to day 36.
# current bookings 4564
# **assigned group number 1972 to day 36.
# current bookings 4570
# **assigned group number 712 to day 36.
# current bookings 4574
# **assigned group number 909 to day 36.
# current bookings 4578
# **assigned group number 2098 to day 36.
# current bookings 4582
# **assigned group number 3457 to day 37.
# current bookings 4589
# **assigned group number 1980 to day 37.
# current bookings 4595
# **assigned group number 2165 to day 37.
# current bookings 4601
# **assigned group number 3280 to day 37.
# current bookings 4607
# **assigned group number 3728 to day 37.
# current bookings 4613
# **assigned group number 4669 to day 37.
# current bookings 4619
# **assigned group number 689 to day 37.
# current bookings 4625
# **assigned group number 1506 to day 37.
# current bookings 4631
# **assigned group number 1683 to day 37.
# current bookings 4637
# **assigned group number 3864 to day 37.
# current bookings 4643
# **assigned group number 439 to day 37.
# current bookings 4649
# **assigned group number 4536 to day 37.
# current bookings 4655
# **assigned group number 285 to day 37.
# current bookings 4661
# **assigned group number 458 to day 37.
# current bookings 4667
# **assigned group number 2963 to day 37.
# current bookings 4673
# **assigned group number 2956 to day 37.
# current bookings 4679
# **assigned group number 2976 to day 37.
# current bookings 4685
# **assigned group number 236 to day 37.
# current bookings 4690
# **assigned group number 509 to day 37.
# current bookings 4695
# **assigned group number 1865 to day 37.
# current bookings 4700
# **assigned group number 2686 to day 37.
# current bookings 4705
# **assigned group number 3959 to day 37.
# current bookings 4710
# **assigned group number 2114 to day 38.
# current bookings 4717
# **assigned group number 4715 to day 38.
# current bookings 4724
# **assigned group number 3051 to day 38.
# current bookings 4731
# **assigned group number 4253 to day 38.
# current bookings 4738
# **assigned group number 3232 to day 38.
# current bookings 4745
# **assigned group number 3326 to day 38.
# current bookings 4752
# **assigned group number 294 to day 38.
# current bookings 4759
# **assigned group number 3345 to day 38.
# current bookings 4766
# **assigned group number 2590 to day 38.
# current bookings 4773
# **assigned group number 2685 to day 38.
# current bookings 4780
# **assigned group number 279 to day 38.
# current bookings 4786
# **assigned group number 948 to day 38.
# current bookings 4792
# **assigned group number 4817 to day 38.
# current bookings 4798
# **assigned group number 943 to day 38.
# current bookings 4804
# **assigned group number 1094 to day 38.
# current bookings 4810
# **assigned group number 1257 to day 38.
# current bookings 4816
# **assigned group number 1915 to day 38.
# current bookings 4822
# **assigned group number 2204 to day 38.
# current bookings 4828
# **assigned group number 3447 to day 38.
# current bookings 4834
# **assigned group number 3644 to day 38.
# current bookings 4840
# **assigned group number 986 to day 39.
# current bookings 4847
# **assigned group number 1582 to day 39.
# current bookings 4854
# **assigned group number 3118 to day 39.
# current bookings 4861
# **assigned group number 2991 to day 39.
# current bookings 4868
# **assigned group number 3659 to day 39.
# current bookings 4875
# **assigned group number 100 to day 39.
# current bookings 4881
# **assigned group number 2472 to day 39.
# current bookings 4887
# **assigned group number 2734 to day 39.
# current bookings 4893
# **assigned group number 2978 to day 39.
# current bookings 4899
# **assigned group number 4100 to day 39.
# current bookings 4905
# **assigned group number 4149 to day 39.
# current bookings 4911
# **assigned group number 4953 to day 39.
# current bookings 4917
# **assigned group number 62 to day 39.
# current bookings 4923
# **assigned group number 1449 to day 39.
# current bookings 4929
# **assigned group number 1932 to day 39.
# current bookings 4935
# **assigned group number 2639 to day 39.
# current bookings 4941
# **assigned group number 2775 to day 39.
# current bookings 4947
# **assigned group number 3174 to day 39.
# current bookings 4953
# **assigned group number 4093 to day 39.
# current bookings 4959
# **assigned group number 4296 to day 39.
# current bookings 4965
# **assigned group number 2148 to day 40.
# current bookings 4972
# **assigned group number 2687 to day 40.
# current bookings 4978
# **assigned group number 3378 to day 40.
# current bookings 4984
# **assigned group number 4808 to day 40.
# current bookings 4990
# **assigned group number 592 to day 40.
# current bookings 4995
# **assigned group number 967 to day 40.
# current bookings 5000
# **assigned group number 1654 to day 40.
# current bookings 5005
# **assigned group number 1714 to day 40.
# current bookings 5010
# **assigned group number 1782 to day 40.
# current bookings 5015
# **assigned group number 2366 to day 40.
# current bookings 5020
# **assigned group number 2917 to day 40.
# current bookings 5025
# **assigned group number 3476 to day 40.
# current bookings 5030
# **assigned group number 3508 to day 40.
# current bookings 5035
# ...
# **assigned group number 3686 to day 44.
# current bookings 5537
# **assigned group number 4450 to day 44.
# current bookings 5543
# **assigned group number 962 to day 44.
# current bookings 5548
# **assigned group number 2357 to day 44.
# current bookings 5553
# **assigned group number 2790 to day 44.
# current bookings 5558
# **assigned group number 3112 to day 44.
# current bookings 5563
# **assigned group number 1164 to day 44.
# current bookings 5568
# **assigned group number 2205 to day 44.
# current bookings 5573
# **assigned group number 2516 to day 44.
# current bookings 5578
# **assigned group number 2802 to day 44.
# current bookings 5583
# **assigned group number 3076 to day 44.
# current bookings 5588
# **assigned group number 156 to day 44.
# current bookings 5593
# **assigned group number 316 to day 44.
# current bookings 5598
# **assigned group number 861 to day 44.
# current bookings 5603
# **assigned group number 3878 to day 45.
# current bookings 5610
# **assigned group number 1235 to day 45.
# current bookings 5616
# **assigned group number 159 to day 45.
# current bookings 5622
# **assigned group number 564 to day 45.
# current bookings 5628
# **assigned group number 1022 to day 45.
# current bookings 5634
# **assigned group number 1122 to day 45.
# current bookings 5640
# **assigned group number 2740 to day 45.
# current bookings 5646
# **assigned group number 3560 to day 45.
# current bookings 5652
# **assigned group number 1873 to day 45.
# current bookings 5658
# **assigned group number 4242 to day 45.
# current bookings 5664
# **assigned group number 4287 to day 45.
# current bookings 5670
# **assigned group number 1888 to day 45.
# current bookings 5676
# **assigned group number 4641 to day 45.
# current bookings 5682
# **assigned group number 4797 to day 45.
# current bookings 5688
# **assigned group number 4876 to day 45.
# current bookings 5694
# **assigned group number 1152 to day 45.
# current bookings 5700
# **assigned group number 3704 to day 45.
# current bookings 5706
# **assigned group number 771 to day 45.
# current bookings 5711
# **assigned group number 798 to day 45.
# current bookings 5716
# **assigned group number 1771 to day 45.
# current bookings 5721
# **assigned group number 1817 to day 45.
# current bookings 5726
# **assigned group number 2654 to day 45.
# current bookings 5731
# **assigned group number 3260 to day 46.
# current bookings 5738
# **assigned group number 2417 to day 46.
# current bookings 5745
# **assigned group number 4928 to day 46.
# current bookings 5752
# **assigned group number 1546 to day 46.
# current bookings 5759
# **assigned group number 4868 to day 46.
# current bookings 5766
# **assigned group number 2514 to day 46.
# current bookings 5773
# **assigned group number 1615 to day 46.
# current bookings 5780
# **assigned group number 938 to day 46.
# current bookings 5786
# **assigned group number 4815 to day 46.
# current bookings 5792
# **assigned group number 764 to day 46.
# current bookings 5798
# **assigned group number 3079 to day 46.
# current bookings 5804
# **assigned group number 3095 to day 46.
# current bookings 5810
# **assigned group number 3416 to day 46.
# current bookings 5816
# **assigned group number 1025 to day 46.
# current bookings 5822
# **assigned group number 2387 to day 46.
# current bookings 5828
# **assigned group number 2795 to day 46.
# current bookings 5834
# **assigned group number 4909 to day 46.
# current bookings 5840
# **assigned group number 1872 to day 46.
# current bookings 5846
# **assigned group number 3921 to day 46.
# current bookings 5852
# **assigned group number 271 to day 46.
# current bookings 5858
# **assigned group number 36 to day 47.
# current bookings 5864
# **assigned group number 1147 to day 47.
# current bookings 5870
# **assigned group number 1690 to day 47.
# current bookings 5876
# **assigned group number 184 to day 47.
# current bookings 5882
# **assigned group number 1109 to day 47.
# current bookings 5888
# **assigned group number 2634 to day 47.
# current bookings 5894
# **assigned group number 2652 to day 47.
# current bookings 5900
# **assigned group number 3772 to day 47.
# current bookings 5906
# **assigned group number 4021 to day 47.
# current bookings 5912
# **assigned group number 4519 to day 47.
# current bookings 5918
# **assigned group number 4523 to day 47.
# current bookings 5924
# **assigned group number 306 to day 47.
# current bookings 5930
# **assigned group number 2076 to day 47.
# current bookings 5936
# **assigned group number 2287 to day 47.
# current bookings 5942
# **assigned group number 2837 to day 47.
# current bookings 5948
# **assigned group number 2862 to day 47.
# current bookings 5954
# **assigned group number 3054 to day 47.
# current bookings 5960
# **assigned group number 164 to day 47.
# current bookings 5966
# **assigned group number 950 to day 47.
# current bookings 5972
# **assigned group number 1536 to day 47.
# current bookings 5978
# **assigned group number 1715 to day 47.
# current bookings 5984
# **assigned group number 404 to day 48.
# current bookings 5991
# **assigned group number 646 to day 48.
# current bookings 5997
# **assigned group number 4189 to day 48.
# current bookings 6003
# **assigned group number 4555 to day 48.
# current bookings 6009
# **assigned group number 2614 to day 48.
# current bookings 6015
# **assigned group number 3444 to day 48.
# current bookings 6021
# **assigned group number 382 to day 48.
# current bookings 6026
# **assigned group number 1512 to day 48.
# current bookings 6031
# **assigned group number 1742 to day 48.
# current bookings 6036
# **assigned group number 2023 to day 48.
# current bookings 6041
# **assigned group number 2616 to day 48.
# current bookings 6046
# **assigned group number 3669 to day 48.
# current bookings 6051
# **assigned group number 4502 to day 48.
# current bookings 6056
# **assigned group number 3078 to day 48.
# current bookings 6061
# **assigned group number 3983 to day 48.
# current bookings 6066
# **assigned group number 4506 to day 48.
# current bookings 6071
# **assigned group number 1356 to day 48.
# current bookings 6076
# **assigned group number 2896 to day 48.
# current bookings 6081
# **assigned group number 7 to day 48.
# current bookings 6086
# **assigned group number 109 to day 48.
# current bookings 6091
# **assigned group number 690 to day 48.
# current bookings 6096
# **assigned group number 2358 to day 48.
# current bookings 6101
# **assigned group number 2919 to day 48.
# current bookings 6106
# **assigned group number 3330 to day 48.
# current bookings 6111
# **assigned group number 716 to day 49.
# current bookings 6117
# **assigned group number 4554 to day 49.
# current bookings 6123
# **assigned group number 4726 to day 49.
# current bookings 6129
# **assigned group number 4986 to day 49.
# current bookings 6135
# **assigned group number 1305 to day 49.
# current bookings 6141
# **assigned group number 952 to day 49.
# current bookings 6147
# **assigned group number 4989 to day 49.
# current bookings 6153
# **assigned group number 1680 to day 49.
# current bookings 6159
# **assigned group number 227 to day 49.
# current bookings 6164
# **assigned group number 877 to day 49.
# current bookings 6169
# **assigned group number 1277 to day 49.
# current bookings 6174
# **assigned group number 3900 to day 49.
# current bookings 6179
# **assigned group number 2197 to day 49.
# current bookings 6184
# **assigned group number 4359 to day 49.
# current bookings 6189
# **assigned group number 4763 to day 49.
# current bookings 6194
# **assigned group number 2159 to day 49.
# current bookings 6199
# **assigned group number 2723 to day 49.
# current bookings 6204
# **assigned group number 4908 to day 49.
# current bookings 6209
# **assigned group number 204 to day 49.
# current bookings 6214
# **assigned group number 2971 to day 49.
# current bookings 6219
# **assigned group number 4251 to day 49.
# current bookings 6224
# **assigned group number 4510 to day 49.
# current bookings 6229
# **assigned group number 3211 to day 49.
# current bookings 6234
# **assigned group number 3419 to day 49.
# current bookings 6239
# **assigned group number 1491 to day 50.
# current bookings 6246
# **assigned group number 4089 to day 50.
# current bookings 6253
# **assigned group number 738 to day 50.
# current bookings 6259
# **assigned group number 4696 to day 50.
# current bookings 6265
# **assigned group number 434 to day 50.
# current bookings 6271
# **assigned group number 4028 to day 50.
# current bookings 6277
# **assigned group number 4483 to day 50.
# current bookings 6283
# **assigned group number 4891 to day 50.
# current bookings 6289
# **assigned group number 176 to day 50.
# current bookings 6295
# **assigned group number 2471 to day 50.
# current bookings 6301
# **assigned group number 3136 to day 50.
# current bookings 6307
# **assigned group number 849 to day 50.
# current bookings 6312
# **assigned group number 990 to day 50.
# current bookings 6317
# **assigned group number 2060 to day 50.
# current bookings 6322
# **assigned group number 2677 to day 50.
# current bookings 6327
# **assigned group number 3701 to day 50.
# current bookings 6332
# **assigned group number 1878 to day 50.
# current bookings 6337
# **assigned group number 2389 to day 50.
# current bookings 6342
# **assigned group number 4458 to day 50.
# current bookings 6347
# **assigned group number 3753 to day 50.
# current bookings 6352
# **assigned group number 1790 to day 50.
# current bookings 6357
# **assigned group number 2518 to day 50.
# current bookings 6362
# **assigned group number 1016 to day 50.
# current bookings 6367
# **assigned group number 4004 to day 51.
# current bookings 6374
# **assigned group number 2392 to day 51.
# current bookings 6380
# **assigned group number 2720 to day 51.
# current bookings 6386
# **assigned group number 3449 to day 51.
# current bookings 6392
# **assigned group number 280 to day 51.
# current bookings 6398
# **assigned group number 1188 to day 51.
# current bookings 6404
# **assigned group number 1789 to day 51.
# current bookings 6410
# **assigned group number 2221 to day 51.
# current bookings 6416
# **assigned group number 1750 to day 51.
# current bookings 6421
# **assigned group number 1828 to day 51.
# current bookings 6426
# **assigned group number 2602 to day 51.
# current bookings 6431
# **assigned group number 3245 to day 51.
# current bookings 6436
# **assigned group number 3405 to day 51.
# current bookings 6441
# **assigned group number 3675 to day 51.
# current bookings 6446
# **assigned group number 4129 to day 51.
# current bookings 6451
# **assigned group number 4385 to day 51.
# current bookings 6456
# **assigned group number 4711 to day 51.
# current bookings 6461
# **assigned group number 4829 to day 51.
# current bookings 6466
# **assigned group number 1326 to day 51.
# current bookings 6471
# **assigned group number 1389 to day 51.
# current bookings 6476
# **assigned group number 3005 to day 51.
# current bookings 6481
# **assigned group number 3197 to day 51.
# current bookings 6486
# **assigned group number 3224 to day 51.
# current bookings 6491
# **assigned group number 4809 to day 51.
# current bookings 6496
# **assigned group number 4096 to day 52.
# current bookings 6503
# **assigned group number 530 to day 52.
# current bookings 6510
# **assigned group number 12 to day 52.
# current bookings 6516
# **assigned group number 1630 to day 52.
# current bookings 6522
# **assigned group number 3168 to day 52.
# current bookings 6528
# **assigned group number 3458 to day 52.
# current bookings 6534
# **assigned group number 4960 to day 52.
# current bookings 6540
# **assigned group number 90 to day 52.
# current bookings 6546
# **assigned group number 3899 to day 52.
# current bookings 6552
# **assigned group number 1699 to day 52.
# current bookings 6558
# **assigned group number 411 to day 52.
# current bookings 6564
# **assigned group number 1487 to day 52.
# current bookings 6570
# **assigned group number 2265 to day 52.
# current bookings 6576
# **assigned group number 4836 to day 52.
# current bookings 6582
# **assigned group number 4030 to day 52.
# current bookings 6588
# **assigned group number 24 to day 52.
# current bookings 6594
# **assigned group number 140 to day 52.
# current bookings 6600
# **assigned group number 893 to day 52.
# current bookings 6606
# **assigned group number 2501 to day 52.
# current bookings 6612
# **assigned group number 151 to day 52.
# current bookings 6618
# **assigned group number 961 to day 52.
# current bookings 6624
# **assigned group number 4033 to day 53.
# current bookings 6631
# **assigned group number 568 to day 53.
# current bookings 6638
# **assigned group number 3085 to day 53.
# current bookings 6645
# **assigned group number 3161 to day 53.
# current bookings 6652
# **assigned group number 1628 to day 53.
# current bookings 6658
# **assigned group number 2528 to day 53.
# current bookings 6664
# **assigned group number 2541 to day 53.
# current bookings 6670
# **assigned group number 4298 to day 53.
# current bookings 6676
# **assigned group number 391 to day 53.
# current bookings 6682
# **assigned group number 1533 to day 53.
# current bookings 6688
# **assigned group number 2690 to day 53.
# current bookings 6694
# **assigned group number 2821 to day 53.
# current bookings 6700
# **assigned group number 3228 to day 53.
# current bookings 6706
# **assigned group number 3355 to day 53.
# current bookings 6712
# **assigned group number 3365 to day 53.
# current bookings 6718
# **assigned group number 628 to day 53.
# current bookings 6724
# **assigned group number 1307 to day 53.
# current bookings 6730
# **assigned group number 2613 to day 53.
# current bookings 6736
# **assigned group number 2887 to day 53.
# current bookings 6742
# **assigned group number 4857 to day 53.
# current bookings 6748
# **assigned group number 2786 to day 53.
# current bookings 6754
# **assigned group number 1097 to day 54.
# current bookings 6761
# **assigned group number 2242 to day 54.
# current bookings 6768
# **assigned group number 4775 to day 54.
# current bookings 6774
# **assigned group number 2604 to day 54.
# current bookings 6780
# **assigned group number 2818 to day 54.
# current bookings 6786
# **assigned group number 4258 to day 54.
# current bookings 6792
# **assigned group number 4474 to day 54.
# current bookings 6798
# **assigned group number 4906 to day 54.
# current bookings 6804
# **assigned group number 890 to day 54.
# current bookings 6810
# **assigned group number 2324 to day 54.
# current bookings 6816
# **assigned group number 3356 to day 54.
# current bookings 6822
# **assigned group number 1171 to day 54.
# current bookings 6828
# **assigned group number 2220 to day 54.
# current bookings 6834
# **assigned group number 914 to day 54.
# current bookings 6840
# **assigned group number 2870 to day 54.
# current bookings 6846
# **assigned group number 860 to day 54.
# current bookings 6852
# **assigned group number 871 to day 54.
# current bookings 6858
# **assigned group number 1360 to day 54.
# current bookings 6864
# **assigned group number 2907 to day 54.
# current bookings 6870
# **assigned group number 603 to day 54.
# current bookings 6877
# **assigned group number 916 to day 54.
# current bookings 6884
# **assigned group number 3806 to day 55.
# current bookings 6890
# **assigned group number 1154 to day 55.
# current bookings 6896
# **assigned group number 1702 to day 55.
# current bookings 6902
# **assigned group number 2093 to day 55.
# current bookings 6908
# **assigned group number 1396 to day 55.
# current bookings 6915
# **assigned group number 3754 to day 55.
# current bookings 6922
# **assigned group number 1334 to day 55.
# current bookings 6927
# **assigned group number 3937 to day 55.
# current bookings 6932
# **assigned group number 4495 to day 55.
# current bookings 6937
# **assigned group number 3082 to day 55.
# current bookings 6942
# **assigned group number 4516 to day 55.
# current bookings 6947
# **assigned group number 357 to day 55.
# current bookings 6952
# **assigned group number 954 to day 55.
# current bookings 6957
# **assigned group number 1145 to day 55.
# current bookings 6962
# **assigned group number 1173 to day 55.
# current bookings 6967
# **assigned group number 3177 to day 55.
# current bookings 6972
# **assigned group number 3237 to day 55.
# current bookings 6977
# **assigned group number 3620 to day 55.
# current bookings 6982
# **assigned group number 3890 to day 55.
# current bookings 6987
# **assigned group number 4547 to day 55.
# current bookings 6992
# **assigned group number 4983 to day 55.
# current bookings 6997
# **assigned group number 2001 to day 55.
# current bookings 7002
# **assigned group number 2038 to day 55.
# current bookings 7007
# **assigned group number 1727 to day 55.
# current bookings 7012
